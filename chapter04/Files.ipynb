# %%
import swimclub

# %%
swimclub.read_swim_data('Darius-13-100m-Fly.txt')
# Out:
# ('Darius',
#  '13',
#  '100m',
#  'Fly',
#  ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30'],
#  '1:26.58')

# %%
data = swimclub.read_swim_data('Darius-13-100m-Fly.txt')

# %%
times = data[4]

times
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
swimmer, age, distance, stroke, times2, average = data

times2
# Out:
# ['1:27.95', '1:21.07', '1:30.96', '1:23.22', '1:27.95', '1:28.30']

# %%
import os

# %%
swim_files = os.listdir(swimclub.FOLDER)

len(swim_files)
# Out:
# 61

# %%
print(swim_files)
# Out:
# ['.DS_Store', 'Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt', 'Elba-14-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie
# ...

# %%
swim_files.remove('.DS_Store')

# %%
print(swim_files)
print(len(swim_files))
# Out:
# ['Abi-10-100m-Back.txt', 'Abi-10-100m-Breast.txt', 'Abi-10-50m-Back.txt', 'Abi-10-50m-Breast.txt', 'Abi-10-50m-Free.txt', 'Ali-12-100m-Back.txt', 'Ali-12-100m-Free.txt', 'Alison-14-100m-Breast.txt', 'Alison-14-100m-Free.txt', 'Aurora-13-50m-Free.txt', 'Bill-18-100m-Back.txt', 'Bill-18-200m-Back.txt', 'Blake-15-100m-Back.txt', 'Blake-15-100m-Fly.txt', 'Blake-15-100m-Free.txt', 'Calvin-9-50m-Back.txt', 'Calvin-9-50m-Fly.txt', 'Calvin-9-50m-Free.txt', 'Carl-15-100m-Back.txt', 'Chris-17-100m-Back.txt', 'Chris-17-100m-Breast.txt', 'Darius-13-100m-Back.txt', 'Darius-13-100m-Breast.txt', 'Darius-13-100m-Fly.txt', 'Darius-13-200m-IM.txt', 'Dave-17-100m-Free.txt', 'Dave-17-200m-Back.txt', 'Elba-14-100m-Free.txt', 'Emma-13-100m-Breast.txt', 'Emma-13-100m-Free.txt', 'Erika-15-100m-Breast.txt', 'Erika-15-100m-Free.txt', 'Erika-15-200m-Breast.txt', 'Hannah-13-100m-Back.txt', 'Hannah-13-100m-Free.txt', 'Katie-9-100m-Back.txt', 'Katie-9-100m-Breast.txt', 'Katie-9-100m-Free.txt', 'Katie-9-50m-Back.t
# ...

# %%
count = 0
for file_name in swim_files:
    count = count + 1
    print(f'{count}: Processing {file_name}')
    swimmer_data = swimclub.read_swim_data(file_name)
    print(swimmer_data)
# Out:
# 1: Processing Abi-10-100m-Back.txt
# ('Abi', '10', '100m', 'Back', ['1:31.59', '1:26.55', '1:28.75', '1:39.79', '1:32.37'], '1:31.81')
# 2: Processing Abi-10-100m-Breast.txt
# ('Abi', '10', '100m', 'Breast', ['1:42.97', '1:43.31', '1:43.50', '1:40.34'], '1:42.53')
# 3: Processing Abi-10-50m-Back.txt
# ('Abi', '10', '50m', 'Back', ['41.50', '43.58', '42.35', '43.35', '39.85', '40.53', '42.14', '39.18', '40.89', '40.89'], '0:41.43')
# 4: Processing Abi-10-50m-Breast.txt
# ('Abi', '10', '50m', 'Breast', ['48.08', '53.17', '45.76', '49.28', '52.85', '46.19', '47.76', '48.83', '45.71', '47.76'], '0:48.54')
# 5: Processing Abi-10-50m-Free.txt
# ('Abi', '10', '50m', 'Free', ['39.07', '37.66', '36.13', '39.42'], '0:38.07')
# 6: Processing Ali-12-100m-Back.txt
# ('Ali', '12', '100m', 'Back', ['1:36.54', '1:39.10', '1:39.45', '1:42.87'], '1:39.49')
# 7: Processing Ali-12-100m-Free.txt
# ...

# %%
for number, file_name in enumerate(swim_files, 1):
    print(number, 'processing:', file_name)
    swimclub.read_swim_data(file_name)
# Out:
# 1 processing: Abi-10-100m-Back.txt
# 2 processing: Abi-10-100m-Breast.txt
# 3 processing: Abi-10-50m-Back.txt
# 4 processing: Abi-10-50m-Breast.txt
# 5 processing: Abi-10-50m-Free.txt
# 6 processing: Ali-12-100m-Back.txt
# 7 processing: Ali-12-100m-Free.txt
# 8 processing: Alison-14-100m-Breast.txt
# 9 processing: Alison-14-100m-Free.txt
# 10 processing: Aurora-13-50m-Free.txt
# 11 processing: Bill-18-100m-Back.txt
# 12 processing: Bill-18-200m-Back.txt
# 13 processing: Blake-15-100m-Back.txt
# 14 processing: Blake-15-100m-Fly.txt
# 15 processing: Blake-15-100m-Free.txt
# 16 processing: Calvin-9-50m-Back.txt
# 17 processing: Calvin-9-50m-Fly.txt
# 18 processing: Calvin-9-50m-Free.txt
# 19 processing: Carl-15-100m-Back.txt
# 20 processing: Chris-17-100m-Back.txt
# 21 processing: Chris-17-100m-Breast.txt
# 22 processing: Darius-13-100m-Back.txt
# 23 processing: Darius-13-100m-Breast.txt
# 24 processing: Darius-13-100m-Fly.txt
# 25 processing: Darius-13-200m-IM.txt
# ...
